# %%
import pandas as pd
import numpy as np
import re
from enum import Enum

# %%
class stage(Enum):
    PRE_FLOP = 0
    POST_FLOP = 1
    TURN = 2
    RIVER = 3
    OVER = 4

# %%
hands = []
hand = {}
stage = stage.PRE_FLOP
players = []
pre_flop = []
post_flop = []
turn = []
river = []
communal_cards = ""
with open('/Users/zacharydawson/artificial-intelligence/poker/data/hand_histories/sample-SBvSB.txt', 'r') as f:
    for line in f.readlines():
        line = line.strip()
        if line.startswith('******************************'):
            hand_stage = ''
            hand['players'] = players
            hand['pre_flop'] = pre_flop
            hand['post_flop'] = post_flop
            hand['turn'] = turn
            hand['river'] = river
            hand['communal_cards'] = communal_cards
            hands.append(hand)
            hand = {}
            stage = stage.PRE_FLOP
            players = []
            pre_flop = []
            post_flop = []
            turn = []
            river = []
        else:
            if re.search('^\s*[0-9]\)', line.strip()) and 'sitting out' not in line:
                components = line.strip().split(' ')
                components = list(filter(lambda a : a != '' and a != '*', components))
                players.append({'name': components[1], 'starting_stack': components[-3:-2], 'hand': (components[-2:-1], components[-1:])})
            elif line.startswith('FLOP'):
                stage = stage.POST_FLOP
                components = line.strip().split(' ')
                components = list(filter(lambda a : a != '' and a != '*', components))
                communal_cards = components[2:]
            elif line.startswith('TURN'):
                stage = stage.TURN
                components = line.strip().split(' ')
                components = list(filter(lambda a : a != '' and a != '*', components))
                communal_cards = components[2:]
            elif line.startswith('RIVER'):
                stage = stage.RIVER
                components = line.strip().split(' ')
                components = list(filter(lambda a : a != '' and a != '*', components))
                communal_cards = components[2:]
            elif 'posts small blind' in line:
                pre_flop.append(line)
            elif 'posts big blind' in line:
                pre_flop.append(line)
            elif 'calls' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
            elif 'checks' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
            elif 'bets' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
            elif 'raises' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
            elif 'folds' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
            elif 'shows' in line:
                if stage == stage.PRE_FLOP:
                    pre_flop.append(line)
                elif stage == stage.POST_FLOP:
                    post_flop.append(line)
                elif stage == stage.TURN:
                    turn.append(line)
                elif stage == stage.RIVER:
                    river.append(line)
                
        
print(hands)
# Out:
# [{'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$1,000'], 'hand': (['2h'], ['5s'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000'], 'hand': (['Jh'], ['Js'])}], 'pre_flop': ['LoggingSimpleBot posts small blind $0.50', 'SimpleBot posts big blind $1', 'LoggingSimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ''}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$999.50'], 'hand': (['Js'], ['7c'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000.50'], 'hand': (['Qs'], ['3c'])}], 'pre_flop': ['SimpleBot posts small blind $0.50', 'LoggingSimpleBot posts big blind $1', 'SimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ''}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$1,000'], 'hand': (['4c'], ['2c'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000'], 'hand': (['6d'], ['2s'])}], 'pre_flop': ['LoggingSimpleBot posts small blind $0.50', 'SimpleBot posts big blind $1', 'LoggingSimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ''}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$999.50'], 'hand': (['Jd'], ['Kd'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000.50'], 'hand': (['Td'], ['6d'])}], 'pre_flop': ['SimpleBot posts small blind $0.50', 'LoggingSimpleBot posts big blind $1', 'SimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ''}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$1,000'], 'hand': (['2h'], ['Kh'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000'], 'hand': (['3c'], ['8c'])}], 'pre_flop': ['LoggingSimpleBot posts small blind $0.50', 'SimpleBot posts big blind $1', 'LoggingSimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ''}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$999.50'], 'hand': (['7d'], ['Qc'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,000.50'], 'hand': (['Th'], ['Kc'])}], 'pre_flop': ['SimpleBot posts small blind $0.50', 'LoggingSimpleBot posts big blind $1', 'SimpleBot calls $0.50', 'LoggingSimpleBot checks'], 'post_flop': ['LoggingSimpleBot checks', 'SimpleBot bets $1', 'LoggingSimpleBot raises $1', 'SimpleBot calls $1'], 'turn': ['LoggingSimpleBot checks', 'SimpleBot bets $2', 'LoggingSimpleBot folds'], 'river': [], 'communal_cards': ['2h', '9h', '4d']}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$996.50'], 'hand': (['6s'], ['9c'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,003.50'], 'hand': (['Jc'], ['6h'])}], 'pre_flop': ['LoggingSimpleBot posts small blind $0.50', 'SimpleBot posts big blind $1', 'LoggingSimpleBot folds'], 'post_flop': [], 'turn': [], 'river': [], 'communal_cards': ['2h', '9h', '4d']}, {'players': [{'name': 'LoggingSimpleBot', 'starting_stack': ['$996'], 'hand': (['5c'], ['5d'])}, {'name': 'SimpleBot', 'starting_stack': ['$1,004'], 'hand': (['4s'], ['Ts'])}], 'pre_flop': ['SimpleBot posts small blind $0.50', 'LoggingSimpleBot posts big blind $1', 'SimpleBot calls $0.50', 'LoggingSimpleBot checks'], 'post_flop': ['LoggingSimpleBot checks', 'SimpleBot bets $1', 'LoggingSimpleBot calls $1'], 'turn': ['LoggingSimpleBot bets $2', 'SimpleBot raises $2', 'LoggingSimpleBot raises $2', 'SimpleBot raises $2', 'LoggingSimpleBot calls $2'], 'river': ['LoggingSimpleBot bets $2', 'SimpleBot raises $2', 'LoggingSimpleBot raises $2', 'SimpleBot raises $2', 'LoggingSimpleBot calls $2', 'SimpleBot shows 4s Ts', 'LoggingSimpleBot shows 5c 5d'], 'communal_cards': ['4c', '6h', '5s', 'Jc']}]
